# %%
print("Hello!")
# Out:
# Hello!

# %%
a = 42

type(a)
# Out:
# int

# %%
a= "Hello"
type(a)

# Python is a dynamically typed language. You can change the type of a variable quite easily. In addition, initializing variables is much easier. In C, you would have to declare 'a' as an integer in order to assign 42 to it, but you wouldn't be able to change the variable to a string.
# Out:
# str

# %%
a = 3.7

type(a)
# Out:
# float

# %%
# type annotation:

a: int = 42
b: int
type (a)
# Out:
# int

# %%
# However, type annotation doesn't change the dynamic properties of python types.

a = "Hello"
type(a)
# Out:
# str

# %%
def count_above(threshold: int, numbers: list[int | float]) -> int:
    c = 0
    for num in numbers:
        if num>threshold:
            c += 1
    return c

print(count_above(10, [20, 30, 5, 6, 50]))
# Out:
# 3

# %%
# As seen, we can compose types like this:

lst: list[int]
    
lst2: list[int | float]

lst = [1, 2, 3, None, 72, None]
